# %% [markdown]
# # NFL Margin of Victory Prediction — Data Setup
# Recreating Warner (2010) with modern data via nflverse.
#
# ## Install dependencies
# Run one of these in your terminal (not in a notebook cell):
#
# **Option A — nflreadpy (recommended, actively maintained):**
# ```bash
# pip install nflreadpy pandas numpy scikit-learn
# ```
#
# **Option B — nfl_data_py (archived but still functional):**
# ```bash
# pip install nfl_data_py pandas numpy scikit-learn
# ```
#
# **Option C — No special package needed at all.** nflverse hosts CSVs on GitHub that you can read directly with pandas. This is the most foolproof approach and what we use below.

# %%
import pandas as pd
import numpy as np

# ============================================================
# 1. SCHEDULES + SCORES + POINT SPREADS
#    This single CSV has game results, home/away scores, and
#    the spread_line for every game since 1999.
# ============================================================
games = pd.read_csv(
    "https://raw.githubusercontent.com/nflverse/nfldata/master/data/games.csv",
    low_memory=False
)

# Filter to regular season, completed games only
games = games[(games["game_type"] == "REG") & (games["result"].notna())].copy()

# result = home_score - away_score (i.e., margin of victory from home perspective)
# spread_line = the Vegas point spread (negative = home favored)
print(f"Total regular-season games: {len(games)}")
print(f"Seasons available: {games['season'].min()} – {games['season'].max()}")
print(f"\nKey columns:")
print(games[["season", "week", "home_team", "away_team",
             "home_score", "away_score", "result", "spread_line"]].head(10))
# Out:
# Total regular-season games: 6967
# Seasons available: 1999 – 2025
#
# Key columns:
#    season  week home_team away_team  home_score  away_score  result  \
# 0    1999     1       ATL       MIN          14          17      -3
# 1    1999     1       CHI        KC          20          17       3
# 2    1999     1       CLE       PIT           0          43     -43
# 3    1999     1        GB       OAK          28          24       4
# 4    1999     1       IND       BUF          31          14      17
# 5    1999     1       JAX        SF          41           3      38
# 6    1999     1        NO       CAR          19          10       9
# 7    1999     1       NYJ        NE          28          30      -2
# 8    1999     1       PHI       ARI          24          25      -1
# 9    1999     1       SEA       DET          20          28      -8
#
#    spread_line
# 0         -4.0
# 1         -3.0
# 2         -6.0
# 3          9.0
# 4         -3.0
# 5          5.5
# 6          3.5
# ...

# %%
games_2000_2007 = games[(games["season"].between(2000, 2007)) & (games["week"] > 4)]
print("Games 2000-2007 w/o first 4 weeks:", len(games_2000_2007))
# Out:
# Games 2000-2007 w/o first 4 weeks: 1554

# %%
# ============================================================
# 2. PLAY-BY-PLAY DATA (for computing team stats)
#    This is the richest dataset — every play from every game.
#    We'll aggregate it into the per-game team stats the paper uses.
#    NOTE: Each season is ~50MB. Start with a few seasons to test.
# ============================================================

# Pick your seasons (the paper used 2000-2009; extend to 2024 for modern data)
SEASONS = list(range(2000, 2025))  # adjust as needed

# Load PBP — this will take a couple minutes for many seasons
pbp_frames = []
for yr in SEASONS:
    url = f"https://github.com/nflverse/nflverse-data/releases/download/pbp/play_by_play_{yr}.csv.gz"
    try:
        df = pd.read_csv(url, compression="gzip", low_memory=False)
        pbp_frames.append(df)
        print(f"  Loaded {yr}: {len(df):,} plays")
    except Exception as e:
        print(f"  Failed {yr}: {e}")

pbp = pd.concat(pbp_frames, ignore_index=True)
print(f"\nTotal plays loaded: {len(pbp):,}")
# Out:
#   Loaded 2000: 45,491 plays
#   Loaded 2001: 44,969 plays
#   Loaded 2002: 47,355 plays
#   Loaded 2003: 46,811 plays
#   Loaded 2004: 46,705 plays
#   Loaded 2005: 46,823 plays
#   Loaded 2006: 46,299 plays
#   Loaded 2007: 46,266 plays
#   Loaded 2008: 45,917 plays
#   Loaded 2009: 46,519 plays
#   Loaded 2010: 46,892 plays
#   Loaded 2011: 47,448 plays
#   Loaded 2012: 47,834 plays
#   Loaded 2013: 48,158 plays
#   Loaded 2014: 47,629 plays
#   Loaded 2015: 48,122 plays
#   Loaded 2016: 47,651 plays
#   Loaded 2017: 47,245 plays
#   Loaded 2018: 47,109 plays
#   Loaded 2019: 47,260 plays
#   Loaded 2020: 47,705 plays
#   Loaded 2021: 49,922 plays
#   Loaded 2022: 49,434 plays
#   Loaded 2023: 49,665 plays
#   Loaded 2024: 49,492 plays
#
# Total plays loaded: 1,184,721

# %%
# ============================================================
# 3. AGGREGATE PBP INTO PER-GAME TEAM STATS
#    Paper's 11 base stats (minus winning %, computed later):
#    OFFENSE (from posteam): points scored, total yards, rush yards,
#                            pass yards, turnovers lost
#    DEFENSE (from defteam): points allowed, total yards allowed,
#                            rush yards allowed, pass yards allowed,
#                            turnovers taken
# ============================================================

plays = pbp[pbp["play_type"].isin(["run", "pass", "qb_kneel", "qb_spike"])].copy()

for col in ["yards_gained", "rushing_yards", "passing_yards", "interception", "fumble_lost"]:
    plays[col] = plays[col].fillna(0)

# --- Offensive stats (grouped by posteam) ---
off_stats = plays.groupby(["season", "week", "posteam", "game_id"]).agg(
    total_yards=("yards_gained", "sum"),
    rush_yards=("rushing_yards", "sum"),
    pass_yards=("passing_yards", "sum"),
    interceptions_thrown=("interception", "sum"),
    fumbles_lost=("fumble_lost", "sum"),
).reset_index()
off_stats["turnovers_lost"] = off_stats["interceptions_thrown"] + off_stats["fumbles_lost"]

# --- Defensive stats (grouped by defteam → renamed to posteam) ---
# "Yards allowed" = yards the opponent gained while YOU were on defense
def_stats = plays.groupby(["season", "week", "defteam", "game_id"]).agg(
    total_yards_allowed=("yards_gained", "sum"),
    rush_yards_allowed=("rushing_yards", "sum"),
    pass_yards_allowed=("passing_yards", "sum"),
    turnovers_taken_int=("interception", "sum"),
    turnovers_taken_fum=("fumble_lost", "sum"),
).reset_index()
def_stats["turnovers_taken"] = def_stats["turnovers_taken_int"] + def_stats["turnovers_taken_fum"]
def_stats = def_stats.rename(columns={"defteam": "posteam"})
def_stats = def_stats[["season", "week", "posteam", "game_id",
                        "total_yards_allowed", "rush_yards_allowed",
                        "pass_yards_allowed", "turnovers_taken"]]

# --- Merge offensive + defensive ---
team_stats = off_stats.merge(def_stats, on=["season", "week", "posteam", "game_id"], how="inner")

# --- Add points from game-level data ---
team_stats = team_stats.merge(
    games[["game_id", "home_team", "away_team", "home_score", "away_score"]],
    on="game_id", how="left"
)
team_stats["points_scored"] = np.where(
    team_stats["posteam"] == team_stats["home_team"],
    team_stats["home_score"],
    team_stats["away_score"]
)
team_stats["points_allowed"] = np.where(
    team_stats["posteam"] == team_stats["home_team"],
    team_stats["away_score"],
    team_stats["home_score"]
)

# --- Clean up: keep the 10 base stats we need ---
base_stats = ["points_scored", "points_allowed",
              "total_yards", "total_yards_allowed",
              "rush_yards", "rush_yards_allowed",
              "pass_yards", "pass_yards_allowed",
              "turnovers_taken", "turnovers_lost"]

team_stats = team_stats[["season", "week", "posteam", "game_id",
                          "home_team", "away_team"] + base_stats]

print(f"Team-game stat rows: {len(team_stats):,}")
print(f"Base stats (10): {base_stats}")
print(f"× H/A (2) × avg+streak (2) + winning% × H/A × avg+streak = 44 features")
team_stats.head()
# Out:
# Team-game stat rows: 13,460
# Base stats (10): ['points_scored', 'points_allowed', 'total_yards', 'total_yards_allowed', 'rush_yards', 'rush_yards_allowed', 'pass_yards', 'pass_yards_allowed', 'turnovers_taken', 'turnovers_lost']
# × H/A (2) × avg+streak (2) + winning% × H/A × avg+streak = 44 features
#    season  week posteam          game_id home_team away_team  points_scored  \
# 0    2000     1     ARI  2000_01_ARI_NYG       NYG       ARI           16.0
# 1    2000     1     ATL   2000_01_SF_ATL       ATL        SF           36.0
# 2    2000     1     BAL  2000_01_BAL_PIT       PIT       BAL           16.0
# 3    2000     1     BUF  2000_01_TEN_BUF       BUF       TEN           16.0
# 4    2000     1     CAR  2000_01_CAR_WAS       WAS       CAR           17.0
#
#    points_allowed  total_yards  total_yards_allowed  rush_yards  \
# 0            21.0        355.0                395.0        43.0
# 1            28.0        359.0                339.0        95.0
# ...

# %%
# ============================================================
# 4. COMPUTE SEASON-TO-DATE AVERAGES & 4-GAME STREAKS
# ============================================================

team_stats = team_stats.sort_values(["season", "posteam", "week"]).reset_index(drop=True)

base_stats = ["points_scored", "points_allowed",
              "total_yards", "total_yards_allowed",
              "rush_yards", "rush_yards_allowed",
              "pass_yards", "pass_yards_allowed",
              "turnovers_taken", "turnovers_lost"]

# Season-to-date expanding mean (all prior games, not including current)
for col in base_stats:
    team_stats[f"{col}_avg"] = (
        team_stats.groupby(["season", "posteam"])[col]
        .transform(lambda x: x.expanding().mean().shift(1))
    )

# 4-game moving average (streak)
for col in base_stats:
    team_stats[f"{col}_streak"] = (
        team_stats.groupby(["season", "posteam"])[col]
        .transform(lambda x: x.rolling(4, min_periods=4).mean().shift(1))
    )

# Cumulative win percentage
team_stats["win"] = (team_stats["points_scored"] > team_stats["points_allowed"]).astype(int)
team_stats["win_pct"] = (
    team_stats.groupby(["season", "posteam"])["win"]
    .transform(lambda x: x.expanding().mean().shift(1))
)

# 4-game winning percentage streak
team_stats["win_pct_streak"] = (
    team_stats.groupby(["season", "posteam"])["win"]
    .transform(lambda x: x.rolling(4, min_periods=4).mean().shift(1))
)

print("Season-to-date and streak features computed.")
print(f"Rows with valid 4-game streak: {team_stats['points_scored_streak'].notna().sum():,}")
# Out:
# Season-to-date and streak features computed.
# Rows with valid 4-game streak: 10,008

# %%
# ============================================================
# 5. BUILD THE MATCHUP-LEVEL TRAINING SET
# ============================================================

feature_cols = (
    [f"{c}_avg" for c in base_stats] +
    [f"{c}_streak" for c in base_stats] +
    ["win_pct", "win_pct_streak"]
)

# Split into home and away team rows
home = team_stats[team_stats["posteam"] == team_stats["home_team"]].copy()
away = team_stats[team_stats["posteam"] == team_stats["away_team"]].copy()

# Rename features with H_ / A_ prefix
home = home.rename(columns={c: f"H_{c}" for c in feature_cols})
away = away.rename(columns={c: f"A_{c}" for c in feature_cols})

# Merge home and away features on game_id
matchups = home[["game_id", "season", "week"] + [f"H_{c}" for c in feature_cols]].merge(
    away[["game_id"] + [f"A_{c}" for c in feature_cols]],
    on="game_id", how="inner"
)

# Add target and spread
matchups = matchups.merge(
    games[["game_id", "result", "spread_line", "home_team", "away_team"]],
    on="game_id", how="left"
)

# Drop rows without enough history (first ~4 weeks of each season)
matchups = matchups.dropna(subset=[f"H_{c}" for c in feature_cols] + [f"A_{c}" for c in feature_cols])

print(f"Final matchup dataset: {len(matchups):,} games")
print(f"Features per game: {len(feature_cols) * 2}")
print(f"  (10 base stats × avg+streak × H/A = 40, plus 2 win_pct = 42)")
print(f"\nTarget (result) stats:")
print(matchups["result"].describe())
matchups.head()
# Out:
# Final matchup dataset: 4,217 games
# Features per game: 44
#   (10 base stats × avg+streak × H/A = 40, plus 2 win_pct = 42)
#
# Target (result) stats:
# count    4217.000000
# mean        2.217453
# std        14.688153
# min       -46.000000
# 25%        -7.000000
# 50%         3.000000
# 75%        10.000000
# max        59.000000
# Name: result, dtype: float64
#            game_id  season  week  H_points_scored_avg  H_points_allowed_avg  \
# 2  2000_06_CLE_ARI    2000     6            17.750000             27.000000
# 3  2000_07_PHI_ARI    2000     7            20.000000             25.800000
# 4   2000_09_NO_ARI    2000     9            17.285714             30.000000
# 5  2000_10_WAS_ARI    2000    10            16.375000             28.875000
# 6  2000_13_NYG_ARI    2000    13            15.454545             28.272727
#
#    H_total_yards_avg  H_total_yards_allowed_avg  H_rush_yards_avg  \
# 2         306.500000                 377.750000         71.000000
# ...

# %%
print('\n'.join(matchups.columns))
# Out:
# game_id
# season
# week
# H_points_scored_avg
# H_points_allowed_avg
# H_total_yards_avg
# H_total_yards_allowed_avg
# H_rush_yards_avg
# H_rush_yards_allowed_avg
# H_pass_yards_avg
# H_pass_yards_allowed_avg
# H_turnovers_taken_avg
# H_turnovers_lost_avg
# H_points_scored_streak
# H_points_allowed_streak
# H_total_yards_streak
# H_total_yards_allowed_streak
# H_rush_yards_streak
# H_rush_yards_allowed_streak
# H_pass_yards_streak
# H_pass_yards_allowed_streak
# H_turnovers_taken_streak
# H_turnovers_lost_streak
# H_win_pct
# H_win_pct_streak
# A_points_scored_avg
# A_points_allowed_avg
# A_total_yards_avg
# A_total_yards_allowed_avg
# A_rush_yards_avg
# A_rush_yards_allowed_avg
# A_pass_yards_avg
# A_pass_yards_allowed_avg
# A_turnovers_taken_avg
# A_turnovers_lost_avg
# A_points_scored_streak
# A_points_allowed_streak
# A_total_yards_streak
# A_total_yards_allowed_streak
# A_rush_yards_streak
# A_rush_yards_allowed_streak
# A_pass_yards_streak
# A_pass_yards_allowed_streak
# ...

# %% [markdown]
# Next steps:
# 1. get ranking system and add computed strength to the dataset
# 2.
#
#
# Questions for Reiter:
# 1. Is a good plan to compute the model in the paper and then make our own with modern data and compare results to the vegas lines?
#     1a. what else should we do for our analysis
# 2. should we try to improve the model at all?

# %%
# ============================================================
# 6. QUICK SANITY CHECK: BASELINE MODEL
#    Compare a simple linear regression vs the spread.
#    (Replace with Gaussian Process for the full paper approach)
# ============================================================

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# Train/test split by season (paper: train 2000-2007, test 2008-2009)
TRAIN_SEASONS = list(range(2000, 2020))
TEST_SEASONS  = list(range(2020, 2025))

X_cols = [f"H_{c}" for c in feature_cols] + [f"A_{c}" for c in feature_cols]

train = matchups[matchups["season"].isin(TRAIN_SEASONS)].dropna(subset=X_cols + ["result"])
test  = matchups[matchups["season"].isin(TEST_SEASONS)].dropna(subset=X_cols + ["result", "spread_line"])

model = LinearRegression()
model.fit(train[X_cols], train["result"])
test = test.copy()
test["pred"] = model.predict(test[X_cols])

mae_model = mean_absolute_error(test["result"], test["pred"])
# spread_line is from the away team perspective in nflverse, so negate it
mae_spread = mean_absolute_error(test["result"], -test["spread_line"])

# Accuracy: did we predict the right winner?
acc_model  = (np.sign(test["pred"]) == np.sign(test["result"])).mean()
acc_spread = (np.sign(-test["spread_line"]) == np.sign(test["result"])).mean()

print("=" * 50)
print(f"{'Metric':<30} {'Model':>8} {'Spread':>8}")
print("-" * 50)
print(f"{'MAE (margin of victory)':<30} {mae_model:>8.2f} {mae_spread:>8.2f}")
print(f"{'Winner accuracy':<30} {acc_model:>7.1%} {acc_spread:>7.1%}")
print("=" * 50)
print(f"\nTest set: {len(test)} games from {TEST_SEASONS[0]}-{TEST_SEASONS[-1]}")
print("\nNext step: swap LinearRegression for a Gaussian Process!")
print("  from sklearn.gaussian_process import GaussianProcessRegressor")
print("  from sklearn.gaussian_process.kernels import RBF, WhiteKernel")

# %% [markdown]
# ## Next Steps
#
# 1. **Gaussian Process**: Replace the linear regression with `sklearn.gaussian_process.GaussianProcessRegressor` using an RBF + WhiteKernel (matches the paper's squared exponential + noise).
#
# 2. **Feature selection**: Implement the forward search from Section 4.1 of the paper.
#
# 3. **Keener rankings**: Compute team strengths via the eigenvalue method in Section 2.2.1.
#
# 4. **Temperature data**: Pull historical weather from Open-Meteo API (free, no key needed):
#    ```python
#    # Example: get avg temp for a city on a given week
#    # https://open-meteo.com/en/docs/historical-weather-api
#    ```
#
# 5. **Betting framework**: Use GP confidence intervals to build the bet-recommendation scheme from Section 4.2.
